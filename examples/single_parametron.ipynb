# %%
using Revise, HarmonicBalance

# %% [markdown]
# # Natural equation for the parametron

# %%
@variables Ω,γ,λ,F, x,θ,η,α, ω0, ω,t,T, ψ, x(t)

natural_equation =  d(d(x,t),t) + γ*d(x,t) + Ω^2*(1-λ*cos(2*ω*t+ψ))*x + α * x^3 + η *d(x,t) * x^2
forces =  F*cos(ω*t+θ)
dEOM = HarmonicBalance.DifferentialEquation(natural_equation + forces, x)
HarmonicBalance.add_harmonic!(dEOM, x, ω);
#HarmonicBalance.add_harmonic!(dEOM, x, 3*ω)

# %%
@time averagedEOM = HarmonicBalance.get_harmonic_equations(dEOM, slow_time=T, fast_time=t)
# Out:
#  90.352690 seconds (131.66 M allocations: 7.473 GiB, 2.63% gc time, 99.27% compilation time)
# A set of 2 harmonic equations
# Variables: u1(T), v1(T)
# Parameters: F, θ, ω, α, γ, η, Ω, λ, ψ
#
# F*cos(θ) + γ*Differential(T)(u1(T)) + (Ω^2)*u1(T) + (3//4)*α*(u1(T)^3) + γ*ω*v1(T) + (2//1)*ω*Differential(T)(v1(T)) + (3//4)*α*(v1(T)^2)*u1(T) + (1//4)*η*ω*(v1(T)^3) + (3//4)*η*(u1(T)^2)*Differential(T)(u1(T)) + (1//4)*η*(v1(T)^2)*Differential(T)(u1(T)) + (1//4)*η*ω*(u1(T)^2)*v1(T) + (1//2)*η*u1(T)*v1(T)*Differential(T)(v1(T)) + (1//2)*λ*(Ω^2)*v1(T)*sin(ψ) - (ω^2)*u1(T) - (1//2)*λ*(Ω^2)*u1(T)*cos(ψ) ~ 0
#
# (Ω^2)*v1(T) + γ*Differential(T)(v1(T)) + (3//4)*α*(v1(T)^3) + (1//4)*η*(u1(T)^2)*Differential(T)(v1(T)) + (3//4)*α*(u1(T)^2)*v1(T) + (3//4)*η*(v1(T)^2)*Differential(T)(v1(T)) + (1//2)*λ*(Ω^2)*u1(T)*sin(ψ) + (1//2)*η*u1(T)*v1(T)*Differential(T)(u1(T)) + (1//2)*λ*(Ω^2)*v1(T)*cos(ψ) - F*sin(θ) - (2//1)*ω*Differential(T)(u1(T)) - (ω^2)*v1(T) - (1//4)*η*ω*(u1(T)^3) - γ*ω*u1(T) - (1//4)*η*ω*(v1(T)^2)*u1(T) ~ 0

# %%
@time problem = HarmonicBalance.Problem(averagedEOM, explicit_Jacobian=true)
# Out:
#   9.560573 seconds (14.74 M allocations: 845.350 MiB, 1.90% gc time, 99.15% compilation time)
# 2 algebraic equations for steady states
# Variables: u1, v1
# Parameters: F, θ, ω, α, γ, η, Ω, λ, ψ
# Symbolic Jacobian: true

# %% [markdown]
# ## sweep parameters

# %%
fixed_parameters = ParameterList(Ω => 1.0,γ => 1E-2, λ => 5E-2, F => 1E-3,  α => 1.,  η=>0.3, θ => 0, ψ => 0)
sweep = ParameterRange(ω => LinRange(0.9, 1.1, 100))
#sweep = ParameterRange(ω => LinRange(0.9, 1.1,15), λ => LinRange(0.0, 0.2, 10))

soln = HarmonicBalance.get_steady_states(problem, sweep, fixed_parameters, random_warmup=true, threading=false)
# Out:
# Tracking 9 paths... 100%|███████████████████████████████| Time: 0:00:13
#   # paths tracked:                  9
#   # non-singular solutions (real):  5 (0)
#   # singular endpoints (real):      0 (0)
#   # total solutions (real):         5 (0)
# A steady state result for 100 parameter points
#
# Solution branches:   5
#    of which real:    5
#    of which stable:  3
#
# Classes: stable, physical, Hopf, binary_labels

# %%
soln=HarmonicBalance.save("parametron_result.jld2", soln);

# %% [markdown]
# # making 1D plots

# %%
HarmonicBalance.plot_1D_solutions(soln, x="ω", y="sqrt(u1^2 + v1^2)", plot_only=["physical"],save_data=true,marker_classification=["stable"]);
# Out:
# PyPlot.Figure(PyObject <Figure size 600x500 with 1 Axes>)
# ┌ Warning: `vendor()` is deprecated, use `BLAS.get_config()` and inspect the output instead
# │   caller = npyinitialize() at numpy.jl:67
# └ @ PyCall /home/hrochan/.julia/packages/PyCall/3fwVL/src/numpy.jl:67
# /usr/lib/python3/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
#user allowed classification
plt = HarmonicBalance.plot_1D_solutions(soln, x="ω", y="sqrt(u1^2 + v1^2)", marker_classification=["ω^15 * sqrt(u1^2 + v1^2) < 0.1" , "cool"])
# Out:
# PyPlot.Figure(PyObject <Figure size 600x500 with 1 Axes>)

# %%
@time HarmonicBalance.LinearResponse.plot_response(soln, LinRange(0.7,1.3,1000), branch=1, logscale=false);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
#  22.716361 seconds (68.85 M allocations: 3.285 GiB, 4.71% gc time, 67.24% compilation time)

# %%
@time spectrum = HarmonicBalance.LinearResponse.plot_jacobian_spectrum(soln, x, branch=1, Ω_range=LinRange(0.6,1.4,300));
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
#   2.670865 seconds (5.63 M allocations: 328.817 MiB, 4.35% gc time, 98.06% compilation time)

# %% [markdown]
# # time-dependent solving

# %%
x0 = [0.0037178842249515134; 0.]
times = (0.,1000.)
dt = 1. # time-resolution of the result (NOT the integration timestep)
fixed_parameters = ParameterList(Ω => 1.0,γ => 1E-2, λ => 5E-2, F => 1E-3,  α => 1., η=>0.3, θ => 0, ψ => 0, ω=>1.)
time_dep = HarmonicBalance.TimeEvolution.ODEProblem(averagedEOM, fixed_parameters, sweep=HarmonicBalance.TimeEvolution.ParameterSweep(), x0 = x0, timespan = times);
time_soln = HarmonicBalance.TimeEvolution.solve(time_dep, saveat=dt);
HarmonicBalance.plot(getindex.(time_soln.u, 1), getindex.(time_soln.u,2))
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x7efd006779d0>
